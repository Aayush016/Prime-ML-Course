# %% [markdown]
# # NumPy

# %%
# NumPy comes with anaconda so we don't need to download it
# pip install numpy ,for installing numpy 
import numpy as np

# %%
l = [1,2,3,4,5] # Make sure the list elements are homogenous
arr = np.array(l)
print(arr)
# Out:
# [1 2 3 4 5]

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>
